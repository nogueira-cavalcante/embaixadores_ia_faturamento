# %%
# !pyinstaller --onefile EmbaixadoresdeIA-Faturamento-SAILibrary_com_logging.py
# Out:
# 859 INFO: PyInstaller: 6.15.0, contrib hooks: 2025.8
# 859 INFO: Python: 3.12.11 (conda)
# 917 INFO: Platform: Windows-11-10.0.22621-SP0
# 917 INFO: Python environment: C:\Users\jpcavalcante\AppData\Local\anaconda3\envs\embaixadores_ia
# 919 INFO: wrote C:\Users\jpcavalcante\OneDrive - Stefanini\Desktop\Embaixadores de IA - Grupo João Cavalcante\Demanda Karolayne\embaixadores_ia_faturamento\EmbaixadoresdeIA-Faturamento-SAILibrary_com_logging.spec
# 930 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\jpcavalcante\\AppData\\Local\\anaconda3\\envs\\embaixadores_ia\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\jpcavalcante\\AppData\\Local\\anaconda3\\envs\\embaixadores_ia\\python312.zip',
#  'C:\\Users\\jpcavalcante\\AppData\\Local\\anaconda3\\envs\\embaixadores_ia\\DLLs',
#  'C:\\Users\\jpcavalcante\\AppData\\Local\\anaconda3\\envs\\embaixadores_ia\\Lib',
#  'C:\\Users\\jpcavalcante\\AppData\\Local\\anaconda3\\envs\\embaixadores_ia',
# ...
